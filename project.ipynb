# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime,date

# %%
data = pd.read_csv(r"C:\Users\Saima Sheikh\Downloads\googleplaystore.csv")

# %%
data.head()
#It shows the first n rows of the dataframe.
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.info()
#It is used to get the concise summary of the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data.groupby(['Category'])[['Price', 'Installs']].agg('sum')\
                    .sort_values(by=['Price', 'Installs'], ascending=[False, False])
# Out:
#                                                                  Price  \
# Category
# 1.9                                                           Everyone
# GAME                 0000000000000000000000000000000000000000000000...
# SHOPPING             0000000000000000000000000000000000000000000000...
# EDUCATION            0000000000000000000000000000000000000000000000...
# FINANCE              0000000000000000000000000000000000000000000000...
# SOCIAL               0000000000000000000000000000000000000000000000...
# ENTERTAINMENT        0000000000000000000000000000000000000000000000...
# TRAVEL_AND_LOCAL     0000000000000000000000000000000000000000000000...
# TOOLS                0000000000000000000000000000000000000000000000...
# PRODUCTIVITY         0000000000000000000000000000000000000000000000...
# NEWS_AND_MAGAZINES   0000000000000000000000000000000000000000000000...
# LIFESTYLE            0000000000000000000000000000000000000000000000...
# ...

# %%
#The countplot is used to represent the occurrence (counts) of the observation present in the categorical variable.
plt.figure(num=None, figsize=(12, 8), facecolor='b', edgecolor='k')
ax =sns.countplot(x='Rating', data=data)
for p in ax.patches:
    value = p.get_height()
    X = p.get_x()+0.4
    Y = p.get_height()+20
    ax.text(X, Y, value, ha="center")
    plt.show()

# %%
import seaborn as sns
# BOXPLOT
sns.boxplot(data.Rating)
# Out:
# C:\Users\Saima Sheikh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating'>

# %%
data.fillna(data.mean())
# Out:
# C:\Users\Saima Sheikh\AppData\Local\Temp\ipykernel_16620\3231489778.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.fillna(data.mean())
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# ...

# %%
data.Rating.mode()
# Out:
# 0    4.4
# Name: Rating, dtype: float64

# %%
from sklearn.impute import SimpleImputer
impo = SimpleImputer(missing_values=np.nan, strategy='mean')
x = data[['Rating']]
X = impo.fit_transform(x)
print(X)
# Out:
# [[4.1       ]
#  [3.9       ]
#  [4.7       ]
#  ...
#  [4.19333832]
#  [4.5       ]
#  [4.5       ]]

# %%
from sklearn.impute import SimpleImputer
impo = SimpleImputer(missing_values=np.nan, strategy='median')
x = data[['Rating']]
X = impo.fit_transform(x)
print(X)
# Out:
# [[4.1]
#  [3.9]
#  [4.7]
#  ...
#  [4.3]
#  [4.5]
#  [4.5]]

# %%
# MEDIAN IMPUTATION
from sklearn.impute import SimpleImputer
impo = SimpleImputer(missing_values=np.nan, strategy='median')
x = data[['Rating']]
print(X)
# Out:
# [[4.1]
#  [3.9]
#  [4.7]
#  ...
#  [4.3]
#  [4.5]
#  [4.5]]

# %%
from sklearn.impute import SimpleImputer
impo = SimpleImputer(missing_values=np.nan, strategy='most_frequent   ')
x = data[['Rating']]
print(X)
# Out:
# [[4.1]
#  [3.9]
#  [4.7]
#  ...
#  [4.3]
#  [4.5]
#  [4.5]]

# %%
## TOTAL MARKET SIZE

total_installs = data["Installs"].sum()
print('Total number of apps\' downloads: +', total_installs)

data['total_profit'] = data['Installs'] * data['Price']
print('Total amount of money spent on paid apps: $', round(df['total_profit'].sum(),2), end='\n')

## TOTAL MARKET SIZE BY INSTALLS && TOTAL_PROFIT

total_cat = data.groupby('Category').sum().sort_values(by='Installs', ascending=False)

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12,16))
_ = sns.barplot(x = total_cat.index, y = 'Installs', data = total_cat, palette="Greens_d", ax=axes[0])
_ = sns.barplot(x = total_cat.index, y = 'total_profit', data = total_cat, palette="Blues_d", ax=axes[1])
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Total number of apps' downloads: + 10,000+500,000+5,000,000+50,000,000+100,000+50,000+50,000+1,000,000+1,000,000+10,000+1,000,000+1,000,000+10,000,000+100,000+100,000+5,000+500,000+10,000+5,000,000+10,000,000+100,000+100,000+500,000+100,000+50,000+10,000+500,000+100,000+10,000+100,000+100,000+50,000+100,000+100,000+10,000+100,000+500,000+5,000,000+10,000+500,000+10,000+100,000+10,000,000+100,000+10,000+10,000,000+100,000+100,000+100,000+100,000+1,000,000+100,000+1,000,000+100,000+100,000+100,000+50,000+100,000+100,000+100,000+10,000+100,000+1,000,000+100,000+100,000+10,000+50,000+5,000,000+100,000+5,000,000+5,000,000+500,000+10,000,000+100,000+500,000+50,000+100,000+1,000,000+100,000+1,000,000+50,000+1,000,000+500,000+100,000+1,000,000+1,000,000+100,000+100,000+1,000,000+100,000+100,000+1,000,000+1,000,000+1,000,000+1,000,000+500,000+500,000+100,000+500,000+1,000,000+100,000+500,000+1,000,000+500,000+100,000+1,000,000+50,000+1,000,000+10,000+1,000,000+100,000+10,000+50,000+100,000+10
# ...

# %%
## PIE CHART FOR FREE VS PAID APPS IN STORE

plt.figure(figsize=(8,8))
count = data['Type'].value_counts()
plt.pie(count, explode=(0.25,0,0.25), labels=['Free', 'Paid','None'], autopct='%1.1f%%', shadow=True, startangle=270)
plt.title('Percent of Free Vs Paid Apps in store', size = 16)
plt.show()

# %%
plt.figure(figsize=(13,10), dpi= 80)
_ = sns.set_context("notebook")
ax = sns.boxplot(x='Rating', y='Category', data=data , notch=False)

ax.set_title('Distribution of App Ratings' , size = 20)
# Out:
# Text(0.5, 1.0, 'Distribution of App Ratings')

# %%
plt.figure(figsize=(10,10))
_ = sns.jointplot(x='Reviews',y='Rating',data=data,color='green',size=9)
plt.title('Rating and Reviews of Jointplot')
plt.show()

# %%
## Content Rating for each of Categories
fig = plt.figure(figsize=(16,8)) 
labels = data['Content Rating'].value_counts(sort = True).index
sizes = data['Content Rating'].value_counts(sort = True)
plt.pie(sizes,labels=labels,autopct='%1.1f%%', shadow=True)
plt.title('Content Rating',size = 20)
plt.show()

# %%
## Count of Content Rating for each group

plt.figure(figsize=(6,3))
fig = sns.countplot(x=data['Content Rating'], palette="hls")
fig.set_xticklabels(fig.get_xticklabels(),rotation=90)
plt.show(fig)

# %%
#Box plot rating vs content rating
_ = sns.catplot(x="Content Rating",y="Rating",data=data, kind="box", height = 10)
plt.xticks(rotation=90)
plt.ylabel("Rating")
plt.title('Box plot Rating VS Content Rating',size = 20)
# Out:
# Text(0.5, 1.0, 'Box plot Rating VS Content Rating')

# %%
#correlation map
# Finding out the correlation between the features
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
## Countplot of each Category

plt.figure(figsize=(20,5))
fig = sns.countplot(x=data['Category'], palette="hls")
fig.set_xticklabels(fig.get_xticklabels(),rotation=90)
plt.show(fig)

# %%
#What are the applications and categories with, most number of reviews, highest rating, most revenue through installs, most number of installs?
cat_columns = ['Reviews', 'Content Rating', 'Rating', 'Installs', 'Price']

for col in cat_columns:
    if col == 'Content Rating':
        rating_cat, rating_count = data['Content Rating'].value_counts().index[0], data['Content Rating'].value_counts()[0]
        print(f"Maximum Content Rating is of : {rating_cat} with a value of {rating_count}", end = '\n')
    else: 
        app, count = data[data[col] == data[col].max()]["App"].iloc[0], data[col].max()
        print(f"Maximum {col} is of {app} with a value of {count}")
# Out:
# Maximum Reviews is of GollerCepte Live Score with a value of 9992
# Maximum Content Rating is of : Everyone with a value of 8714
# Maximum Rating is of Life Made WI-Fi Touchscreen Photo Frame with a value of 19.0
# Maximum Installs is of Life Made WI-Fi Touchscreen Photo Frame with a value of Free
# Maximum Price is of Life Made WI-Fi Touchscreen Photo Frame with a value of Everyone
